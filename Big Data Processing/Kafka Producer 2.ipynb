# %%
#produce (key, value) where key identifies the producer and value is a piece of data from streaming file
# (producer2, row_values)
#each producer sends data to the same topic but with a unique key

# %%
# import statements
from time import sleep
from json import dumps
from json import loads
from kafka import KafkaProducer
import random
import datetime as dt
import pandas as pd

# %% [markdown]
# # Producer 2
# This program writes records to Kafka topic `assignment`. Each record has `key = "parsed"` and value equal to a (key, value pair) where the key identifies the producer and the value contains a dictionary object with the data for a random row. THis random row is decided by choosing a random integer in the interval $[0, df.shape[0])$ where the enpoint refers to the number of rows in the dataset.

# %% [markdown]
# ### Reading in climate streaming data and creating a function to extract row values

# %%
aqua_data = pd.read_csv("hotspot_AQUA_streaming.csv")

# %%
aqua_data.head()
# Out:
#    latitude  longitude  confidence  surface_temperature_celcius
# 0   -37.623    149.323          51                           38
# 1   -38.038    142.986          65                           40
# 2   -37.950    142.366          92                           70
# 3   -38.231    147.172          83                           60
# 4   -37.903    145.250          53                           44

# %%
#this function takes in a dataframe and a row number and returns a dictionary variable containing the row data
#for the given dataframe in the required data model format. The station is set to a constant value since it is not 
#a variable in the climate_streaming dataset and date 

#date columns are set to no date as the date data will be extracted from the climate_streaming data in producer1

def extract_row_data(data, row_number, producer_id="producer2"):
    #convert row_data to a string with single quotes on either side so that it can be converted back to 
    #a json object using the loads funcion from the json library
        row_data = {"latitude": data.iloc[row_number]["latitude"],
                "longitude": data.iloc[row_number]["longitude"],
                "datetime": "no date",
                "confidence": int(data.iloc[row_number]["confidence"]),
                "date": "no date",
                "surface_temperature_celcius": int(data.iloc[row_number]["surface_temperature_celcius"])}
        

        
        return [producer_id, row_data]

# %%
def publish_message(producer_instance, topic_name, key, value):
    try:
        key_bytes = bytes(key, encoding='utf-8')
        value_bytes = bytes(value, encoding='utf-8')
        producer_instance.send(topic_name, key=key_bytes, value=value_bytes)
        producer_instance.flush()
        print('Message published successfully. Data: ' + str(data))
    except Exception as ex:
        print('Exception in publishing message.')
        print(str(ex))
        
def connect_kafka_producer():
    _producer = None
    try:
        _producer = KafkaProducer(bootstrap_servers=['localhost:9092'],
                                  api_version=(0, 10))
    except Exception as ex:
        print('Exception while connecting Kafka.')
        print(str(ex))
    finally:
        return _producer
    
if __name__ == '__main__':
   
    topic = 'assignment'
    
    print('Publishing records..')
    producer = connect_kafka_producer()

    for e in range(500):

        #select row_number randomly from the list of all rows
        row_number = random.randrange(0, aqua_data.shape[0])
        
        #get our data
        data = extract_row_data(aqua_data, row_number, producer_id="producer2")
        
        #convert data to a string using the json dumps function
        data = dumps(data)
        
        publish_message(producer, topic, 'parsed', data)
        sleep(2)
# Out:
# Publishing records..
# Message published successfully. Data: ["producer2", {"latitude": -38.038000000000004, "longitude": 142.986, "datetime": "no date", "confidence": 65, "date": "no date", "surface_temperature_celcius": 40}]
# Message published successfully. Data: ["producer2", {"latitude": -35.0821, "longitude": 142.4532, "datetime": "no date", "confidence": 83, "date": "no date", "surface_temperature_celcius": 57}]
# Message published successfully. Data: ["producer2", {"latitude": -36.0933, "longitude": 141.7154, "datetime": "no date", "confidence": 63, "date": "no date", "surface_temperature_celcius": 35}]
# Message published successfully. Data: ["producer2", {"latitude": -36.3168, "longitude": 145.7285, "datetime": "no date", "confidence": 100, "date": "no date", "surface_temperature_celcius": 103}]
# Message published successfully. Data: ["producer2", {"latitude": -36.3831, "longitude": 145.7276, "datetime": "no date", "confidence": 71, "date": "no date", "surface_temperature_celcius": 45}]
# Message published successfully. Data: ["producer2", {"latitude": -35.9187, "longitude": 143.9828, "datetime": "no date", "confidence": 79, "date": "no date", "surface_temperature_celcius": 52}]
# Message published successfully. Data: ["producer2", {"latitude": -35.4993, "longitude": 143.3105, "datetime": "no date", "confidence": 84, "date": "no date", "surface_temperature_celcius": 57}]
# Message published successfully. Data: ["producer2", {"latitude": -36.6483, "longitude": 142.4878, "datetime": "no date", "confidence": 60, "date": "no date", "surface_temperature_celcius": 41}]
# Message published successfully. Data: ["producer2", {"latitude": -37.2891, "longitude": 143.5697, "datetime": "no date", "confidence": 76, "date": "no date", "surface_temperature_celcius": 50}]
# Message published successfully. Data: ["producer2", {"latitude": -37.7021, "longitude": 145.5536, "datetime": "no date", "confidence": 88, "date": "no date", "surface_temperature_celcius": 42}]
# Message published successfully. Data: ["producer2", {"latitude": -37.5043, "longitude": 146.3299, "datetime": "no date", "confidence": 100, "date": "no date", "surface_temperature_celcius": 93}]
# Message published successfully. Data: ["producer2", {"latitude": -37.6674, "longitude": 142.2687, "datetime": "no date", "confidence": 65, "date": "no date", "surface_temperature_celcius": 42}]
# Message published successfully. Data: ["producer2", {"latitude": -36.0844, "longitude": 141.4934, "datetime": "no date", "confidence": 81, "date": "no date", "surface_temperature_celcius": 71}]
# Message published successfully. Data: ["producer2", {"latitude": -36.7845, "longitude": 141.4518, "datetime": "no date", "confidence": 86, "date": "no date", "surface_temperature_celcius": 60}]
# Message published successfully. Data: ["producer2", {"latitude": -37.135999999999996, "longitude": 141.7239, "datetime": "no date", "confidence": 68, "date": "no date", "surface_temperature_celcius": 44}]
# Message published successfully. Data: ["producer2", {"latitude": -38.0524, "longitude": 141.6738, "datetime": "no date", "confidence": 76, "date": "no date", "surface_temperature_celcius": 49}]
# Message published successfully. Data: ["producer2", {"latitude": -36.3551, "longitude": 141.0343, "datetime": "no date", "confidence": 71, "date": "no date", "surface_temperature_celcius": 46}]
# Message published successfully. Data: ["producer2", {"latitude": -34.385999999999996, "longitude": 142.0503, "datetime": "no date", "confidence": 81, "date": "no date", "surface_temperature_celcius": 54}]
# Message published successfully. Data: ["producer2", {"latitude": -35.7421, "longitude": 142.5634, "datetime": "no date", "confidence": 60, "date": "no date", "surface_temperature_celcius": 40}]
# Message published successfully. Data: ["producer2", {"latitude": -37.8375, "longitude": 143.4153, "datetime": "no date", "confidence": 52, "date": "no date", "surface_temperature_celcius": 39}]
# Message published successfully. Data: ["producer2", {"latitude": -37.635, "longitude": 149.303, "datetime": "no date", "confidence": 52, "date": "no date", "surface_temperature_celcius": 47}]
# Message published successfully. Data: ["producer2", {"latitude": -34.2568, "longitude": 141.64, "datetime": "no date", "confidence": 51, "date": "no date", "surface_temperature_celcius": 42}]
# Message published successfully. Data: ["producer2", {"latitude": -36.4624, "longitude": 141.0446, "datetime": "no date", "confidence": 78, "date": "no date", "surface_temperature_celcius": 51}]
# Message published successfully. Data: ["producer2", {"latitude": -36.0434, "longitude": 143.1899, "datetime": "no date", "confidence": 58, "date": "no date", "surface_temperature_celcius": 40}]
# Message published successfully. Data: ["producer2", {"latitude": -36.3156, "longitude": 141.4514, "datetime": "no date", "confidence": 84, "date": "no date", "surface_temperature_celcius": 57}]
# Message published successfully. Data: ["producer2", {"latitude": -38.1544, "longitude": 143.7961, "datetime": "no date", "confidence": 81, "date": "no date", "surface_temperature_celcius": 54}]
# Message published successfully. Data: ["producer2", {"latitude": -36.