# %%
#produce (key, value) where key identifies the producer and value is a piece of data from streaming file
# (producer3, row_values)
#each producer sends data to the same topic but with a unique key

# %%
# import statements
from time import sleep
from json import dumps
from json import loads
from kafka import KafkaProducer
import random
import datetime as dt
import pandas as pd

# %% [markdown]
# # Producer 3
# This program writes records to Kafka topic `assignment`. Each record has `key = "parsed"` and value equal to a (key, value pair) where the key identifies the producer and the value contains a dictionary object with the data for a random row. THis random row is decided by choosing a random integer in the interval $[0, df.shape[0])$ where the enpoint refers to the number of rows in the dataset.

# %% [markdown]
# ### Reading in climate streaming data and creating a function to extract row values

# %%
terra_data = pd.read_csv("hotspot_TERRA_streaming.csv")

# %%
terra_data.head()
# Out:
#    latitude  longitude  confidence  surface_temperature_celcius
# 0   -37.966    145.051          78                           68
# 1   -35.541    143.311          82                           63
# 2   -35.554    143.307          67                           53
# 3   -35.543    143.316          86                           67
# 4   -37.708    145.100          80                           54

# %%
#this function takes in a dataframe and a row number and returns a dictionary variable containing the row data
#for the given dataframe in the required data model format. The station is set to a constant value since it is not 
#a variable in the climate_streaming dataset and date 

#date columns are set to no date as the date data will be extracted from the climate_streaming data in producer1

def extract_row_data(data, row_number, producer_id="producer2"):
    #convert row_data to a string with single quotes on either side so that it can be converted back to 
    #a json object using the loads funcion from the json library
        row_data = {"latitude": data.iloc[row_number]["latitude"],
                "longitude": data.iloc[row_number]["longitude"],
                "datetime": "no date",
                "confidence": int(data.iloc[row_number]["confidence"]),
                "date": "no date",
                "surface_temperature_celcius": int(data.iloc[row_number]["surface_temperature_celcius"])}
        

        
        return [producer_id, row_data]

# %%
def publish_message(producer_instance, topic_name, key, value):
    try:
        key_bytes = bytes(key, encoding='utf-8')
        value_bytes = bytes(value, encoding='utf-8')
        producer_instance.send(topic_name, key=key_bytes, value=value_bytes)
        producer_instance.flush()
        print('Message published successfully. Data: ' + str(data))
    except Exception as ex:
        print('Exception in publishing message.')
        print(str(ex))
        
def connect_kafka_producer():
    _producer = None
    try:
        _producer = KafkaProducer(bootstrap_servers=['localhost:9092'],
                                  api_version=(0, 10))
    except Exception as ex:
        print('Exception while connecting Kafka.')
        print(str(ex))
    finally:
        return _producer
    
if __name__ == '__main__':
   
    topic = 'assignment'
    
    print('Publishing records..')
    producer = connect_kafka_producer()
    
    for e in range(500):
        
        #select row_number randomly from the list of all rows
        row_number = random.randrange(0, terra_data.shape[0])
        
        #get our data
        data = extract_row_data(terra_data, row_number, producer_id="producer3")
        
        #convert data to a string using the json dumps function
        data = dumps(data)
        
        publish_message(producer, topic, 'parsed', data)
        sleep(2)
# Out:
# Publishing records..
# Message published successfully. Data: ["producer3", {"latitude": -38.0812, "longitude": 143.2335, "datetime": "no date", "confidence": 80, "date": "no date", "surface_temperature_celcius": 54}]
# Message published successfully. Data: ["producer3", {"latitude": -36.8264, "longitude": 142.6138, "datetime": "no date", "confidence": 77, "date": "no date", "surface_temperature_celcius": 50}]
# Message published successfully. Data: ["producer3", {"latitude": -38.167, "longitude": 143.841, "datetime": "no date", "confidence": 51, "date": "no date", "surface_temperature_celcius": 38}]
# Message published successfully. Data: ["producer3", {"latitude": -36.3999, "longitude": 144.737, "datetime": "no date", "confidence": 100, "date": "no date", "surface_temperature_celcius": 88}]
# Message published successfully. Data: ["producer3", {"latitude": -38.3343, "longitude": 143.8644, "datetime": "no date", "confidence": 59, "date": "no date", "surface_temperature_celcius": 43}]
# Message published successfully. Data: ["producer3", {"latitude": -36.1963, "longitude": 145.194, "datetime": "no date", "confidence": 72, "date": "no date", "surface_temperature_celcius": 46}]
# Message published successfully. Data: ["producer3", {"latitude": -37.425, "longitude": 148.107, "datetime": "no date", "confidence": 100, "date": "no date", "surface_temperature_celcius": 50}]
# Message published successfully. Data: ["producer3", {"latitude": -36.5511, "longitude": 146.7819, "datetime": "no date", "confidence": 56, "date": "no date", "surface_temperature_celcius": 34}]
# Message published successfully. Data: ["producer3", {"latitude": -37.3165, "longitude": 147.4932, "datetime": "no date", "confidence": 93, "date": "no date", "surface_temperature_celcius": 72}]
# Message published successfully. Data: ["producer3", {"latitude": -36.4074, "longitude": 145.9085, "datetime": "no date", "confidence": 74, "date": "no date", "surface_temperature_celcius": 48}]
# Message published successfully. Data: ["producer3", {"latitude": -36.0933, "longitude": 141.7154, "datetime": "no date", "confidence": 63, "date": "no date", "surface_temperature_celcius": 35}]
# Message published successfully. Data: ["producer3", {"latitude": -36.3973, "longitude": 141.8273, "datetime": "no date", "confidence": 76, "date": "no date", "surface_temperature_celcius": 49}]
# Message published successfully. Data: ["producer3", {"latitude": -36.8174, "longitude": 142.6118, "datetime": "no date", "confidence": 100, "date": "no date", "surface_temperature_celcius": 104}]
# Message published successfully. Data: ["producer3", {"latitude": -36.304, "longitude": 143.7445, "datetime": "no date", "confidence": 59, "date": "no date", "surface_temperature_celcius": 40}]
# Message published successfully. Data: ["producer3", {"latitude": -34.8421, "longitude": 141.5266, "datetime": "no date", "confidence": 71, "date": "no date", "surface_temperature_celcius": 45}]
# Message published successfully. Data: ["producer3", {"latitude": -36.2756, "longitude": 145.811, "datetime": "no date", "confidence": 50, "date": "no date", "surface_temperature_celcius": 39}]
# Message published successfully. Data: ["producer3", {"latitude": -36.883, "longitude": 142.1637, "datetime": "no date", "confidence": 79, "date": "no date", "surface_temperature_celcius": 67}]
# Message published successfully. Data: ["producer3", {"latitude": -36.4216, "longitude": 141.2799, "datetime": "no date", "confidence": 60, "date": "no date", "surface_temperature_celcius": 40}]
# Message published successfully. Data: ["producer3", {"latitude": -36.0157, "longitude": 145.9414, "datetime": "no date", "confidence": 92, "date": "no date", "surface_temperature_celcius": 70}]
# Message published successfully. Data: ["producer3", {"latitude": -35.4533, "longitude": 143.2029, "datetime": "no date", "confidence": 85, "date": "no date", "surface_temperature_celcius": 66}]
# Message published successfully. Data: ["producer3", {"latitude": -36.4622, "longitude": 142.4773, "datetime": "no date", "confidence": 83, "date": "no date", "surface_temperature_celcius": 57}]
# Message published successfully. Data: ["producer3", {"latitude": -37.
]
# Message published successfully. Data: ["producer3", {"latitude": -36.1546, "longitude": 141.8146, "datetime": "no date", "confidence": 88, "date": "no date", "surface_temperature_celcius": 74}]
# Message published successfully. Data: ["producer3", {"latitude": -37.5687, "longitude": 143.2121, "datetime": "no date", "confidence": 62, "date": "no date", "surface_temperature_celcius": 41}]
# Message published successfully. Data: ["producer3", {"latitude": -36.1112, "longitude": 146.5388, "datetime": "no date", "confidence": 67, "date": "no date", "surface_temperature_celcius": 43}]
# Message published successfully. Data: ["producer3", {"latitude": -36.8616, "longitude": 142.8025, "datetime": "no date", "confidence": 90, "date": "no date", "surface_temperature_celcius": 78}]
# Message published successfully. Data: ["producer3", {"latitude": -36.5642, "longitude": 142.5943, "datetime": "no date", "confidence": 51, "date": "no date", "surface_temperature_celcius": 38}]
# Message published successfully. Data: ["producer3", {"latitude": -37.8937, "longitude": 147.1785, "datetime": "no date", "confidence": 51, "date": "no date", "surface_temperature_celcius": 38}]
# Message published successfully. Data: ["producer3", {"latitude": -37.8375, "longitude": 143.4153, "datetime": "no date", "confidence": 52, "date": "no date", "surface_temperature_celcius": 39}]
# Message published successfully. Data: ["producer3", {"latitude": -37.0924, "longitude": 141.89700000000002, "datetime": "no date", "confidence": 97, "date": "no date", "surface_temperature_celcius": 80}]
# Message published successfully. Data: ["producer3", {"latitude": -38.3871, "longitude": 146.3082, "datetime": "no date", "confidence": 78, "date": "no date", "surface_temperature_celcius": 51}]
# Message published successfully. Data: ["producer3", {"latitude": -35.4173, "longitude": 143.2041, "datetime": "no date", "confidence": 54, "date": "no date", "surface_temperature_celcius": 39}]
# Message published successfully. Data: ["producer3", {"latitude": -37.3165, "longitude": 147.4932, "datetime": "no date", "confidence": 93, "date": "no date", "surface_temperature_celcius": 72}]
# Message published successfully. Data: ["producer3", {"latitude": -36.7309, "longitude": 147.1227, "datetime": "no date", "confidence": 89, "date": "no date", "surface_temperature_celcius": 42}]
# Message published successfully. Data: ["producer3", {"latitude": -36.4348, "longitude": 141.3, "datetime": "no date", "confidence": 78, "date": "no date", "surface_temperature_celcius": 52}]
# Message published successfully. Data: ["producer3", {"latitude": -37.3601, "longitude": 145.8519, "datetime": "no date", "confidence": 82, "date": "no date", "surface_temperature_celcius": 62}]
# Message published successfully. Data: ["producer3", {"latitude": -38.0219, "longitude": 141.2238, "datetime": "no date", "confidence": 76, "date": "no date", "surface_temperature_celcius": 62}]
# Message published successfully. Data: ["producer3", {"latitude": -38.036, "longitude": 143.9012, "datetime": "no date", "confidence": 67, "date": "no date", "surface_temperature_celcius": 45}]
# Message published successfully. Data: ["producer3", {"latitude": -37.9071, "longitude": 143.53799999999998, "datetime": "no date", "confidence": 100, "date": "no date", "surface_temperature_celcius": 88}]
# Message published successfully. Data: ["producer3", {"latitude": -37.294000000000004, "longitude": 141.232, "datetime": "no date", "confidence": 100, "date": "no date", "surface_temperature_celcius": 87}]
# Message published successfully. Data: ["producer3", {"latitude": -36.2209, "longitude": 141.5804, "datetime": "no date", "confidence": 67, "date": "no date", "surface_temperature_celcius": 43}]
# Message published successfully. Data: ["producer3", {"latitude": -36.4032, "longitude": 144.0604, "datetime": "no date", "confidence": 69, "date": "no date", "surface_temperature_celcius": 45}]
# Message published successfully. Data: ["producer3", {"latitude": -36.301, "longitude": 143.2349, "datetime": "no date", "confidence": 70, "date": "no date", "surface_temperature_celcius": 45}]
# Message published successfully. Data: ["producer3", {"latitude": -35.554, "longitude": 143.30700000000002, "datetime": "no date", "confidence": 67, "date": "no date", "surface_temperature_celcius": 53}]
# Message published successfully. Data: ["producer3", {"latitude": -35.6871, "longitude": 143.5235, "datetime": "no date", "confidence": 90, "date": "no date", "surface_temperature_celcius": 68}]
# Message published successfully. Data: ["producer3", {"latitude": -36.8922, "longitude": 145.1252, "datetime": "no date", "confidence": 60, "date": "no date", "surface_temperature_celcius": 40}]
# Message published successfully. Data: ["producer3", {"latitude": -36.3874, "longitude": 144.8724, "datetime": "no date", "confidence": 78, "date": "no date", "surface_temperature_celcius": 51}]
# Message published successfully. Data: ["producer3", {"latitude": -36.4611, "longitude": 143.14600000000002, "datetime": "no date", "confidence": 55, "date": "no date", "surface_temperature_celcius": 48}]
# Message published successfully. Data: ["producer3", {"latitude": -36.1815, "longitude": 142.09, "datetime": "no date", "confidence": 78, "date": "no date", "surface_temperature_celcius": 52}]
# Message published successfully. Data: ["producer3", {"latitude": -36.0852, "longitude": 141.7112, "datetime": "no date", "confidence": 100, "date": "no date", "surface_temperature_celcius": 64}]
