# %% [markdown]
# # Initial Setup
# All new data is stored into two new collections called climate_partb and hotspot_partb which both follow the exact same data models as the previous questions. This is done simply to keep things organised

# %%
import pymongo
from pymongo import MongoClient

client = MongoClient()
db = client.fit3182_assignment_db
collection_climate_partb = db.climate_partb
collection_hotspot_partb = db.hotspot_partb

# %% [markdown]
# First, import our database client, spark session entry point, and some basic spark sql functions for data transformation.

# %%
from pymongo import MongoClient
from pyspark.sql import SparkSession
from pyspark.sql.functions import col, split, element_at, when

from json import dumps
from json import loads
import pygeohash as pgh
import numpy as np
import datetime as dt
import random

# %% [markdown]
# Set a global variable to store topic name.

# %%
topic_name = 'assignment'

# %% [markdown]
# Initialize our spark session with `#threads = #logicalCPU` and the given application name.

# %%
spark = (
    SparkSession.builder
    .master('local[*]')
    .appName('[Demo] Spark Streaming from Kafka into MongoDB')
    .getOrCreate()
)

# %% [markdown]
# Create a streaming dataframe with options providing the bootstrap server(s) and topic name.

# %%
topic_stream_df = (
    spark.readStream.format('kafka')
    .option('kafka.bootstrap.servers', 'localhost:9092')
    .option('subscribe', topic_name)
    .load()
)

# %% [markdown]
# We can print the schema for this dataframe to see what columns we have to work with.

# %%
topic_stream_df.printSchema()
# Out:
# root
#  |-- key: binary (nullable = true)
#  |-- value: binary (nullable = true)
#  |-- topic: string (nullable = true)
#  |-- partition: integer (nullable = true)
#  |-- offset: long (nullable = true)
#  |-- timestamp: timestamp (nullable = true)
#  |-- timestampType: integer (nullable = true)

# %%
#we make changes to our topic_stream in the process_batches function
output_stream_df = topic_stream_df

# %% [markdown]
# Define a utility class to process the rows of our streaming dataframe.

# %%
class DbWriter:
    # called at the start of processing each partition in each output micro-batch
    def open(self, partition_id, epoch_id):
        self.mongo_client = MongoClient(
            host='localhost',
            port=27017
        )
        self.db = self.mongo_client['fit3182_db']
        return True
    
    # called once per row of the result dataframe
    # the current code DOES NOT handle duplicate processing
    #   e.g., query fails and restarts just before current micro-batch was fully inserted
    def process(self, row):
        self.db[topic_name].insert_one(row.asDict())
    
    # called once all rows have been processed (possibly with error)
    def close(self, err):
        self.mongo_client.close()

# %% [markdown]
# Now, define our stream writer for the MongoDB database sink.

# %% [markdown]
# # Process Batch
# Here we process the incoming data by checking whether there is a fire and then storing the information in the relevant collections. There are print statements that print the incoming raw data and then the collection in which the data was stored and whether the was no fire, natural fire or other fire

# %%
def process_batch(batch_df, batch_id):
    raw_data = batch_df.collect()
    
    #store each row in our batch to rows_in_batch
    rows_in_batch = []
    
    #get each row in batch and append all rows to rows_in_batch
    for row in raw_data:
        
        #get the value row as a string
        x = row.value
        x = x.decode()
        
        #use the json loads function to convert our string into an array containing our producerid and our 
        #json object
        x = loads(x)
        
        rows_in_batch.append(x)
        
    #DELETE LATER
    print("rows_in_batch")
    print(rows_in_batch)
    
    
    #check if there is climate data, check is True if there is climate_data
    check, climate_data = check_climate_data_present(rows_in_batch)
    
    if check:
        
        #calculate geohash for climate_data
        climate_geohash = get_geohash(climate_data, precision=3)
        
        #get all hotspot data with same geohash as climate_geohash
        hotspot_data = group_by_location(rows_in_batch, climate_geohash)
        
        #if no hotspot data, we just append the climate_data at the end
        
        #else if there is more than one hotspot (the precision 3 geohash is the same)
        if len(hotspot_data) > 1:
            
            #group hotspot_data by geohash of precision 5
            hotspot_data = group_by_location_precision5(hotspot_data)
            
            #merge the hotspot_data groups
            hotspot_data = merge_hotspot(hotspot_data)
            
        
        #insert data into collection_hotspot_partb for every hotspot in hotspot_data
        for i in range(len(hotspot_data)):
            
            #check if fire was natural
            if climate_data[1]["air_temperature_celcius"] > 20 and climate_data[1]["GHI_w/m2"] > 180:
                
                #create json object to insert into collection
                #date and datetime is used from our climate_data
                #a random number of hours between 0 and 23 is added to datetime
                random_hours = random.randrange(0, 23)
                datetime_random_hours = dt.datetime.strptime(climate_data[1]["date"],"%d/%m/%Y")
                datetime_random_hours += dt.timedelta(hours=random_hours)
                
                newEntry = {"latitude": hotspot_data[i][1]["latitude"],
                            "longitude": hotspot_data[i][1]["longitude"],
                            "datetime": datetime_random_hours,
                            "confidence": int(hotspot_data[i][1]["confidence"]),
                            "date": dt.datetime.strptime(climate_data[1]["date"],"%d/%m/%Y"),
                            "surface_temperature_celcius": int(hotspot_data[i][1]["surface_temperature_celcius"]),
                            "cause_of_fire" : "natural"}
                
                #insert into collection_hotspot_partb
                collection_hotspot_partb.insert_one(newEntry)
                
                #DELETE LATER
                print("natural fire")
                print("natural fire")
                print("natural fire")
                print("natural fire")
                print(newEntry)
                print("\n")
        
            
            #else if fire cause was other
            else:
                
                #create json object to insert into collection
                #date and datetime is used from our climate_data
                #a random number of hours between 0 and 23 is added to datetime
                random_hours = random.randrange(0, 23)
                datetime_random_hours = dt.datetime.strptime(climate_data[1]["date"],"%d/%m/%Y")
                datetime_random_hours += dt.timedelta(hours=random_hours)
                
                newEntry = {"latitude": hotspot_data[i][1]["latitude"],
                            "longitude": hotspot_data[i][1]["longitude"],
                            "datetime": datetime_random_hours,
                            "confidence": int(hotspot_data[i][1]["confidence"]),
                            "date": dt.datetime.strptime(climate_data[1]["date"],"%d/%m/%Y"),
                            "surface_temperature_celcius": int(hotspot_data[i][1]["surface_temperature_celcius"]),
                            "cause_of_fire" : "other"}
                
                #insert into collection_hotspot_partb
                collection_hotspot_partb.insert_one(newEntry)
                
                #DELETE LATER
                print("other fire")
                print("other fire")
                print("other fire")
                print("other fire")
                print(newEntry)
                print("\n")
                
    
        #insert climate data into collection_climate_partb
        climate_data[1]["date"] = dt.datetime.strptime(climate_data[1]["date"],"%d/%m/%Y")
        newEntry = climate_data[1]
        collection_climate_partb.insert_one(newEntry)

        #DELETE LATER
        print("no fire")
        print(newEntry)
        print("\n")

# %% [markdown]
# # Helper Functions
# Here we have all the helper functions that were used to simplify our code in the process_batch() function. These helper functions have their use commented on top of them

# %%
#this function returns the geohash value for a given row of data
def get_geohash(row_data, precision=3):
    return pgh.encode(row_data[1]["latitude"], row_data[1]["longitude"], precision)
    

#this function takes in a geohash for the climate data and returns all hotspot data with the same geohash of 
#precision 3
def group_by_location(rows_in_batch, climate_geohash):    
    res = []
    
    for i in range(len(rows_in_batch)):
        if rows_in_batch[i][0] != 'producer1' and get_geohash(rows_in_batch[i], precision=3) == climate_geohash:
            res.append(rows_in_batch[i])
            
        return res

#this function returns True and the row itself if rows_in_batch contains data from producer1 else False
def check_climate_data_present(rows_in_batch):
    for i in range(len(rows_in_batch)):
        if rows_in_batch[i][0] == 'producer1':
            return True, rows_in_batch[i]
    
    return False, False

#this function groups together the hotspot data based on their geohash of precision5
def group_by_location_precision5(hotspot_data):
    
    #loop through hotspot_data and add any new geohash to keys array and group together data with same geohash valu
    keys = []
    groups = []
    
    for i in range(len(hotspot_data)):
        geohash = get_geohash(hotspot_data[i], precision=5)
        
        if geohash in keys:
            index = keys.index(geohash)
            
            groups[index].append(hotspot_data[i])
            
        else:
            keys.append(geohash)
            groups.append([hotspot_data[i]])
            
    return groups


#this function merges hotspot_data groups that were previously grouped together
def merge_hotspot(hotspot_data_groups):
    res = []
    
    for hotspot_data in hotspot_data_groups:
        
        #if more than one hotspot in the group
        if len(hotspot_data) > 1:
    
            #average all latitudes
            avg_latitude = []
            for i in range(len(hotspot_data)):
                avg_latitude.append(hotspot_data[i][1]["latitude"])
            avg_latitude = sum(avg_latitude) / len(avg_latitude)

            #average all longitudes
            avg_longitude = []
            for i in range(len(hotspot_data)):
                avg_longitude.append(hotspot_data[i][1]["longitude"])
            avg_longitude = sum(avg_longitude) / len(avg_longitude)

            #average all confidences
            avg_confidence = []
            for i in range(len(hotspot_data)):
                avg_confidence.append(hotspot_data[i][1]["confidence"])
            avg_confidence = sum(avg_confidence) / len(avg_confidence)

            #average all surface tempteratures
            avg_surface_temperature_celcius = []
            for i in range(len(hotspot_data)):
                avg_surface_temperature_celcius.append(hotspot_data[i][1]["surface_temperature_celcius"])
            avg_surface_temperature_celcius = sum(avg_surface_temperature_celcius) / len(avg_surface_temperature_celcius)

            avg_data = {"latitude": avg_latitude,
                        "longitude": avg_longitude,
                        "datetime": "no date",
                        "confidence": avg_confidence,
                        "date": "no date",
                        "surface_temperature_celcius": avg_surface_temperature_celcius}
            
            #since we cant merge the name of producer2 and producer3, we just put it as producer2
            res.append(["producer2", avg_data])
            
        else:
            #single hotspot in group
            avg_data = hotspot_data[0]
            
            #since we cant merge the name of producer2 and producer3, we just put it as producer2
            res.append(hotspot_data[0])
    
    return res

# %%
db_writer = (
    output_stream_df
    .writeStream
    .outputMode('append')
    .trigger(processingTime="10 seconds")
    .foreachBatch(process_batch)
)

# %% [markdown]
# The variable `writer` points to the stream writer we wish to use.

# %%
# change this variable to either db_writer or console_logger to get output to the desired sink
writer = db_writer

# %% [markdown]
# Now we can start our streaming query. The workflow is straightforward.
# 1. Call the `StreamWriter` object's `start` method to begin execution of the query.
# 1. The `query` variable allows us to manage the running query. This is a simple demo, so we use `awaitTermination` to block our driver program until the streaming query is stopped due to failure or user-interrupts.
#
# You can press CTRL-C in the notebook to stop the running query anytime.

# %%
try:
    query = writer.start()
    query.awaitTermination()
except KeyboardInterrupt:
    print('Interrupted by CTRL-C. Stopped query')
except StreamingQueryException as exc:
    print(exc)
finally:
    query.stop()
# Out:
# rows_in_batch
# []
# rows_in_batch
# [['producer2', {'latitude': -37.7021, 'longitude': 145.5536, 'datetime': 'no date', 'confidence': 88, 'date': 'no date', 'surface_temperature_celcius': 42}], ['producer3', {'latitude': -36
 'datetime': 'no date', 'confidence': 80, 'date': 'no date', 'surface_temperature_celcius': 58}], ['producer1', {'station': 1, 'date': '14/01/2022', 'air_temperature_celcius': 15, 'relative_humidity': 41.6, 'windspeed_knots': 15.0, 'max_wind_speed': 28.0, 'precipitation': ' 0.00I', 'GHI_w/m2': 138, 'latitude': -37.396, 'longitude': 148.086}], ['producer2', {'latitude': -36.1751, 'longitude': 142.7831, 'datetime': 'no date', 'confidence': 67, 'date': 'no date', 'surface_temperature_celcius': 43}], ['producer3', {'latitude': -35.6871, 'longitude': 143.5235, 'datetime': 'no date', 'confidence': 90, 'date': 'no date', 'surface_temperature_celcius': 68}]]
# no fire
# {'station': 1, 'date': datetime.datetime(2022, 1, 14, 0, 0), 'air_temperature_celcius': 15, 'relative_humidity': 41.6, 'windspeed_knots': 15.0, 'max_wind_speed': 28.0, 'precipitation': ' 0.00I', 'GHI_w/m2': 138, 'latitude': -37.396, 'longitude': 148.086, '_id': ObjectId('628b45728240717ef08b4857')}
#
#
# rows_in_batch
# [['producer2', {'latitude': -36.2044, 'longitude': 145.7706, 'datetime': 'no date', 'confidence': 58, 'date': 'no date', 'surface_temperature_celcius': 51}], ['producer3', {'latitude': -36.391, 'longitude': 144.5747, 'datetime': 'no date', 'confidence': 85, 'date': 'no date', 'surface_temperature_celcius': 60}], ['producer2', {'latitude': -36.6118, 'longitude': 143.5275, 'datetime': 'no date', 'confidence': 77, 'date': 'no date', 'surface_temperature_celcius': 50}], ['producer3', {'latitude': -36.7817, 'longitude': 142.4872, 'datetime': 'no date', 'confidence': 72, 'date': 'no date', 'surface_temperature_celcius': 46}], ['producer2', {'latitude': -36.2567, 'longitude': 142.4903, 'datetime': 'no date', 'confidence': 82, 'date': 'no date', 'surface_temperature_celcius': 55}], ['producer3', {'latitude': -36.009, 'longitude': 143.185, 'datetime': 'no date', 'confidence': 72, 'date': 'no date', 'surface_temperature_celcius': 39}], ['producer2', {'latitude': -36.8846, 'longitude': 145.1679, 'datetime': 'no date', 'confidence': 79, 'date': 'no date', 'surface_temperature_celcius': 52}], ['producer3', {'latitude': -37.7815, 'longitude': 143.1338, 'datetime': 'no date', 'confidence': 84, 'date': 'no date', 'surface_temperature_celcius': 58}], ['producer1', {'station': 1, 'date': '15/01/2022', 'air_temperature_celcius': 11, 'relative_humidity': 43.8, 'windspeed_knots': 6.5, 'max_wind_speed': 12.0, 'precipitation': ' 0.02G', 'GHI_w/m2': 99, 'latitude': -37.365, 'longitude': 148.05200000000002}], ['producer2', {'latitude': -36.1002, 'longitude': 142.3405, 'datetime': 'no date', 'confidence': 96, 'date': 'no date', 'surface_temperature_celcius': 78}], ['producer3', {'latitude': -36.91, 'longitude': 141.2705, 'datetime': 'no date', 'confidence': 100, 'date': 'no date', 'surface_temperature_celcius': 96}]]
# no fire
# {'station': 1, 'date': datetime.datetime(2022, 1, 15, 0, 0), 'air_temperature_celcius': 11, 'relative_humidity': 43.8, 'windspeed_knots': 6.5, 'max_wind_speed': 12.0, 'precipitation': ' 0.02G', 'GHI_w/m2': 99, 'latitude': -37.365, 'longitude': 148.05200000000002, '_id': ObjectId('628b457c8240717ef08b4858')}
# rows_in_batch
# [['producer2', {'latitude': -37.1945, 'longitude': 148.8074, 'datetime': 'no date', 'confidence': 83, 'date': 'no date', 'surface_temperature_celcius': 57}], ['producer3', {'latitude': -37.4621, 'longitude': 143.0869, 'datetime': 'no date', 'confidence': 75, 'date': 'no date', 'surface_temperature_celcius': 48}], ['producer2', {'latitude': -36.5023, 'longitude': 143.6038, 'datetime': 'no date', 'confidence': 85, 'date': 'no date', 'surface_temperature_celcius': 66}], ['producer3', {'latitude': -36.1198, 'longitude': 145.6369, 'datetime': 'no date', 'confidence': 79, 'date': 'no date', 'surface_temperature_celcius': 52}], ['producer2', {'latitude': -37.7856, 'longitude': 143.4095, 'datetime': 'no date', 'confidence': 67, 'date': 'no date', 'surface_temperature_celcius': 43}], ['producer3', {'latitude': -34.2782, 'longitude': 142.2253, 'datetime': 'no date', 'confidence': 81, 'date': 'no date', 'surface_temperature_celcius': 54}], ['producer2', {'latitude': -36.7084, 'longitude': 142.7354, 'datetime': 'no date', 'confidence': 64, 'date': 'no date', 'surface_temperature_celcius': 42}], ['producer3', {'latitude': -37.978, 'longitude': 145.623, 'datetime': 'no date', 'confidence': 84, 'date': 'no date', 'surface_temperature_celcius': 59}], ['producer1', {'station': 1, 'date': '16/01/2022', 'air_temperature_celcius': 10, 'relative_humidity': 45.9, 'windspeed_knots': 3.2, 'max_wind_speed': 7.0, 'precipitation': ' 0.00G', 'GHI_w/m2': 89, 'latitude': -37.461, 'longitude': 148.10299999999998}], ['producer2', {'latitude': -36.284, 'longitude': 146.145, 'datetime': 'no date', 'confidence': 100, 'date': 'no date', 'surface_temperature_celcius': 54}], ['producer3', {'latitude': -38.2391, 'longitude': 142.82, 'datetime': 'no date', 'confidence': 92, 'date': 'no date', 'surface_temperature_celcius': 71}]]
# other fire
# other fire
# other fire
# other fire
# {'latitude': -37.1945, 'longitude': 148.8074, 'datetime': datetime.datetime(2022, 1, 16, 0, 0), 'confidence': 83, 'date': datetime.datetime(2022, 1, 16, 0, 0), 'surface_temperature_celcius': 57, 'cause_of_fire': 'other', '_id': ObjectId('628b45868240717ef08b4859')}
#
#
# no fire
# {'station': 1, 'date': datetime.datetime(2022, 1,
 'datetime': 'no date', 'confidence': 79, 'date': 'no date', 'surface_temperature_celcius': 52}], ['producer3', {'latitude': -36.5262, 'longitude': 144.5737, 'datetime': 'no date', 'confidence': 98, 'date': 'no date', 'surface_temperature_celcius': 84}], ['producer1', {'station': 1, 'date': '19/01/2022', 'air_temperature_celcius': 12, 'relative_humidity': 47.9, 'windspeed_knots': 6.7, 'max_wind_speed': 11.1, 'precipitation': ' 0.00G', 'GHI_w/m2': 105, 'latitude': -36.4125, 'longitude': 143.1189}], ['producer2', {'latitude': -37.8078, 'longitude': 143.3482, 'datetime': 'no date', 'confidence': 85, 'date': 'no date', 'surface_temperature_celcius': 60}], ['producer3', {'latitude': -36.4315, 'longitude': 141.1987, 'datetime': 'no date', 'confidence': 76, 'date': 'no date', 'surface_temperature_celcius': 49}]]
# no fire
# {'station': 1, 'date': datetime.datetime(2022, 1, 19, 0, 0), 'air_temperature_celcius': 12, 'relative_humidity': 47.9, 'windspeed_knots': 6.7, 'max_wind_speed': 11.1, 'precipitation': ' 0.00G', 'GHI_w/m2': 105, 'latitude': -36.4125, 'longitude': 143.1189, '_id': ObjectId('628b45a48240717ef08b485d')}
# rows_in_batch
# [['producer2', {'latitude': -36.7223, 'longitude': 143.9213, 'datetime': 'no date', 'confidence': 73, 'date': 'no date', 'surface_temperature_celcius': 47}], ['producer3', {'latitude': -36.1941, 'longitude': 143.1604, 'datetime': 'no date', 'confidence': 93, 'date': 'no date', 'surface_temperature_celcius': 72}], ['producer2', {'latitude': -36.2403, 'longitude': 141.4047, 'datetime': 'no date', 'confidence': 64, 'date': 'no date', 'surface_temperature_celcius': 42}], ['producer3', {'latitude': -36.7842, 'longitude': 146.9658, 'datetime': 'no date', 'confidence': 53, 'date': 'no date', 'surface_temperature_celcius': 39}], ['producer2', {'latitude': -36.8293, 'longitude': 141.9382, 'datetime': 'no date', 'confidence': 79, 'date': 'no date', 'surface_temperature_celcius': 52}], ['producer3', {'latitude': -36.4309, 'longitude': 141.1436, 'datetime': 'no date', 'confidence': 80, 'date': 'no date', 'surface_temperature_celcius': 54}], ['producer2', {'latitude': -36.9576, 'longitude': 141.5387, 'datetime': 'no date', 'confidence': 70, 'date': 'no date', 'surface_temperature_celcius': 45}], ['producer3', {'latitude': -37.5812, 'longitude': 142.7374, 'datetime': 'no date', 'confidence': 94, 'date': 'no date', 'surface_temperature_celcius': 75}], ['producer1', {'station': 1, 'date': '20/01/2022', 'air_temperature_celcius': 21, 'relative_humidity': 58.8, 'windspeed_knots': 8.8, 'max_wind_speed': 22.9, 'precipitation': ' 0.08G', 'GHI_w/m2': 167, 'latitude': -36.358000000000004, 'longitude': 143.113}], ['producer2', {'latitude': -37.7851, 'longitude': 141.4593, 'datetime': 'no date', 'confidence': 52, 'date': 'no date', 'surface_temperature_celcius': 38}], ['producer3', {'latitude': -36.3704, 'longitude': 143.0191, 'datetime': 'no date', 'confidence': 76, 'date': 'no date', 'surface_temperature_celcius': 49}]]
# no fire
# {'station': 1, 'date': datetime.datetime(2022, 1, 20, 0, 0), 'air_temperature_celcius': 21, 'relative_humidity': 58.8, 'windspeed_knots': 8.8, 'max_wind_speed': 22.9, 'precipitation': ' 0.08G', 'GHI_w/m2': 167, 'latitude': -36.358000000000004, 'longitude': 143.113, '_id': ObjectId('628b45ae8240717ef08b485e')}
#
#
# rows_in_batch
# [['producer2', {'latitude': -37.8668, 'longitude': 143.0472, 'datetime': 'no date', 'confidence': 69, 'date': 'no date', 'surface_temperature_celcius': 44}], ['producer3', {'latitude': -36.0973, 'longitude': 143.4279, 'datetime': 'no date', 'confidence': 87, 'date': 'no date', 'surface_temperature_celcius': 92}], ['producer2', {'latitude': -36.5871, 'longitude': 144.4958, 'datetime': 'no date', 'confidence': 93, 'date': 'no date', 'surface_temperature_celcius': 72}], ['producer3', {'latitude': -37.856, 'longitude': 143.416, 'datetime': 'no date', 'confidence': 75, 'date': 'no date', 'surface_temperature_celcius': 41}], ['producer2', {'latitude': -37.333, 'longitude': 143.534, 'datetime': 'no date', 'confidence': 88, 'date': 'no date', 'surface_temperature_celcius': 58}], ['producer3', {'latitude': -36.9085, 'longitude': 141.2821, 'datetime': 'no date', 'confidence': 77, 'date': 'no date', 'surface_temperature_celcius': 50}], ['producer2', {'latitude': -37.8947, 'longitude': 142.8497, 'datetime': 'no date', 'confidence': 76, 'date': 'no date', 'surface_temperature_celcius': 49}], ['producer3', {'latitude': -36.8847, 'longitude': 141.0956, 'datetime': 'no date', 'confidence': 87, 'date': 'no date', 'surface_temperature_celcius': 62}], ['producer1', {'station': 1, 'date': '21/01/2022', 'air_temperature_celcius': 21, 'relative_humidity': 61.1, 'windspeed_knots': 6.6, 'max_wind_speed': 11.1, 'precipitation': ' 0.00I', 'GHI_w/m2': 163, 'latitude': -37.189, 'longitude': 146.791}], ['producer2', {'latitude': -36.4624, 'longitude': 141.0446, 'datetime': 'no date', 'confidence': 78, 'date': 'no date', 'surface_temperature_celcius': 51}], ['producer3', {'latitude': -37.8412, 'longitude': 147.2536, 'datetime': 'no date', 'confidence': 100, 'date': 'no date', 'surface_temperature_celcius': 87}]]
# no fire
# {'station': 1, 'date': datetime.datetime(2022, 1, 21, 0, 0), 'air_temperature_celcius': 21, 'relative_humidity': 61.1, 'windspeed_knots': 6.6, 'max_wind_speed': 11.1, 'precipitation': ' 0.00I', 'GHI_w/m2': 163, 'latitude': -37.189, 'longitude': 146.791, '_id': ObjectId('628b45b88240717ef08b485f')}
#
#
# rows_in_batch
# [['producer2', {'latitude': -37.602, 'longitude': 149.311, 'datetime': 'no date', 'confidence': 81, 'date': 'no date', 'surface_temperature_celcius': 55}], ['producer3', {'latitude': -36.9045, 'longitude': 141.9823, 'datetime': 'no date', 'confidence': 100, 'date': 'no date', 'surface_temperature_celcius': 113}], ['producer2', {'latitude': -36.1558, 'longitude': 145.9723, 'datetime': 'no date', 'confidence': 80, 'date': 'no date', 'surface_temperature_celcius': 53}], ['producer3', {'latitude': -37.5612, 'longitude': 144.7701, 'datetime': 'no date', 'confidence': 73, 'date': 'no date', 'surface_temperature_celcius': 49}], ['producer2', {'latitude': -36.4306, 'longitude': 141.5645, 'datetime': 'no date', 'confidence': 74, 'date': 'no date', 'surface_temperature_celcius': 48}], ['producer3', {'latitude': -37.441, 'longitude': 142.9966, 'datetime': 'no date', 'confidence': 65, 'date': 'no date', 'surface_temperature_celcius': 42}], ['producer2', {'latitude': -37.0038, 'longitude': 142.1629, 'datetime': 'no date', 'confidence': 68, 'date': 'no date', 'surface_temperature_celcius': 44}], ['producer3', {'latitude': -37.2904, 'longitude': 143.9209, 'datetime': 'no date', 'confidence': 55, 'date': 'no date', 'surface_temperature_celcius': 39}], ['producer1', {'station': 1, 'date': '22/01/2022', 'air_temperature_celcius': 14, 'relative_humidity': 51.0, 'windspeed_knots': 9.9, 'max_wind_speed': 15.0, 'precipitation': ' 0.00I', 'GHI_w/m2': 119, 'latitude': -37.38, 'longitude': 148.053}], ['producer2', {'latitude': -37.4756, 'longitude': 145.6779, 'datetime': 'no date', 'confidence': 72, 'date': 'no date', 'surface_temperature_celcius': 46}], ['producer3', {'latitude': -37.605, 'longitude': 149.308, 'datetime': 'no date', 'confidence': 68, 'date': 'no date', 'surface_temperature_celcius': 43}]]
# no fire
# {'station': 1, 'date': datetime.datetime(2022, 1, 22, 0, 0), 'air_temperature_celcius': 14, 'relative_humidity': 51.0, 'windspeed_knots': 9.9, 'max_wind_speed': 15.0, 'precipitation': ' 0.00I', 'GHI_w/m2': 119, 'latitude': -37.38, 'longitude': 148.053, '_id': ObjectId('628b45c28240717ef08b4860')}
#
#
# rows_in_batch
# [['producer2', {'latitude': -36.1247, 'longitude': 145.1437, 'datetime': 'no date', 'confidence': 71, 'date': 'no date', 'surface_temperature_celcius': 46}], ['producer3', {'latitude': -37.1929, 'longitude': 143.8132, 'datetime': 'no date', 'confidence': 59, 'date': 'no date', 'surface_temperature_celcius': 45}], ['producer2', {'latitude': -37.8757, 'longitude': 143.428, 'datetime': 'no date', 'confidence': 66, 'date': 'no date', 'surface_temperature_celcius': 43}], ['producer3', {'latitude': -37.4688, 'longitude': 145.98, 'datetime': 'no date', 'confidence': 87, 'date': 'no date', 'surface_temperature_celcius': 62}], ['producer2', {'latitude': -36.1048, 'longitude': 145.5791, 'datetime': 'no date', 'confidence': 80, 'date': 'no date', 'surface_temperature_celcius': 53}], ['producer3', {'latitude': -35.325, 'longitude': 143.497, 'datetime': 'no date', 'confidence': 77, 'date': 'no date', 'surface_temperature_celcius': 36}], ['producer2', {'latitude': -36.4909, 'longitude': 146.7406, 'datetime': 'no date', 'confidence': 73, 'date': 'no date', 'surface_temperature_celcius': 47}], ['producer3', {'latitude': -36.7318, 'longitude': 141.4603, 'datetime': 'no date', 'confidence': 70, 'date': 'no date', 'surface_temperature_celcius': 45}], ['producer1', {'station': 1, 'date': '23/01/2022', 'air_temperature_celcius': 8, 'relative_humidity': 38.6, 'windspeed_knots': 12.8, 'max_wind_speed': 18.1, 'precipitation': ' 0.31G', 'GHI_w/m2': 75, 'latitude': -36.5548, 'longitude': 142.5237}], ['producer2', {'latitude': -37.7795, 'longitude': 148.4084, 'datetime': 'no date', 'confidence': 79, 'date': 'no date', 'surface_temperature_celcius': 53}], ['producer3', {'latitude': -36.0156, 'longitude': 143.2188, 'datetime': 'no date', 'confidence': 66, 'date': 'no date', 'surface_temperature_celcius': 43}]]
# no fire
# {'station': 1, 'date': datetime.datetime(2022, 1, 23, 0, 0), 'air_temperature_celcius': 8, 'relative_humidity': 38.6, 'windspeed_knots': 12.8, 'max_wind_speed': 18.1, 'precipitation': ' 0.31G', 'GHI_w/m2': 75, 'latitude': -36.5548, 'longitude': 142.5237, '_id': ObjectId('628b45cc8240717ef08b4861')}
# rows_in_batch
# [['producer2', {'latitude': -36.6667, 'longitude': 143.7526, 'datetime': 'no date', 'confidence': 71, 'date': 'no date', 'surface_temperature_celcius': 45}], ['producer3', {'latitude': -36.4113, 'longitude': 141.1671, 'datetime': 'no date', 'confidence': 82, 'date': 'no date', 'surface_temperature_celcius': 55}], ['producer2', {'latitude': -36.7159, 'longitude': 141.3991, 'datetime': 'no date', 'confidence': 75, 'date': 'no date', 'surface_temperature_celcius': 49}], ['producer3', {'latitude': -37.8704, 'longitude': 142.5842, 'datetime': 'no date', 'confidence': 74, 'date': 'no date', 'surface_temperature_celcius': 48}], ['producer2', {'latitude': -36.1546, 'longitude': 141.8146, 'datetime': 'no date', 'confidence': 88, 'date': 'no date', 'surface_temperature_celcius': 74}], ['producer3', {'latitude': -37.2794, 'longitude': 143.5903, 'datetime': 'no date', 'confidence': 51, 'date': 'no date', 'surface_temperature_celcius': 44}], ['producer2', {'latitude': -37.365, 'longitude': 148.05200000000002, 'datetime': 'no date', 'confidence': 90, 'date': 'no date', 'surface_temperature_celcius': 63}], ['producer3', {'latitude': -35.2791, 'longitude': 142.5659, 'datetime': 'no date', 'confidence': 63, 'date': 'no date', 'surface_temperature_celcius': 49}], ['producer1', {'station': 1, 'date': '24/01/2022', 'air_temperature_celcius': 9, 'relative_humidity': 45.3, 'windspeed_knots': 2.5, 'max_wind_speed': 6.0, 'precipitation': ' 0.00G', 'GHI_w/m2': 80, 'latitude': -36.851, 'longitude': 148.11700000000002}], ['producer2', {'latitude': -37.982, 'longitude': 143.6422, 'datetime': 'no date', 'confidence': 56, 'date': 'no date', 'surface_temperature_celcius': 42}], ['producer3', {'latitude': -36.779, 'longitude': 146.108, 'datetime': 'no date', 'confidence': 61, 'date': 'no date', 'surface_temperature_celcius': 32}]]
# no fire
# {'station': 1, 'date': datetime.datetime(2022, 1, 24, 0, 0), 'air_temperature_celcius': 9, 'relative_humidity': 45.3, 'windspeed_knots': 2.5, 'max_wind_speed': 6.0, 'precipitation': ' 0.00G', 'GHI_w/m2': 80, 'latitude': -36.851, 'longitude': 148.11700000000002, '_id': ObjectId('628b45d68240717ef08b4862')}
#
#
# rows_in_batch
# [['producer2', {'latitude': -37.5158, 'longitude': 142.8257, 'datetime': 'no date', 'confidence': 64, 'date': 'no date', 'surface_temperature_celcius': 42}], ['producer3', {'latitude': -37.4935, 'longitude': 142.8492, 'datetime': 'no date', 'confidence': 77, 'date': 'no date', 'surface_temperature_celcius': 52}], ['producer2', {'latitude': -37.9422, 'longitude': 143.6199, 'datetime': 'no date', 'confidence': 53, 'date': 'no date', 'surface_temperature_celcius': 39}], ['producer3', {'latitude': -37.0884, 'longitude': 141.0357, 'datetime': 'no date', 'confidence': 81, 'date': 'no date', 'surface_temperature_celcius': 55}], ['producer2', {'latitude': -34.3616, 'longitude': 141.6477, 'datetime': 'no date', 'confidence': 85, 'date': 'no date', 'surface_temperature_celcius': 60}], ['producer3', {'latitude': -36.5507, 'longitude': 142.5788, 'datetime': 'no date', 'confidence': 83, 'date': 'no date', 'surface_temperature_celcius': 57}], ['producer2', {'latitude': -37.903, 'longitude': 141.0975, 'datetime': 'no date', 'confidence': 84, 'date': 'no date', 'surface_temperature_celcius': 59}], ['producer3', {'latitude': -37.8025, 'longitude': 143.4677, 'datetime': 'no date', 'confidence': 77, 'date': 'no date', 'surface_temperature_celcius': 50}], ['producer1', {'station': 1, 'date': '25/01/2022', 'air_temperature_celcius': 11, 'relative_humidity': 43.2, 'windspeed_knots': 5.5, 'max_wind_speed': 8.0, 'precipitation': ' 0.00G', 'GHI_w/m2': 100, 'latitude': -37.376, 'longitude': 148.042}], ['producer2', {'latitude': -37.1104, 'longitude': 141.828, 'datetime': 'no date', 'confidence': 77, 'date': 'no date', 'surface_temperature_celcius': 50}], ['producer3', {'latitude': -37.4322, 'longitude': 143.1602, 'datetime': 'no date', 'confidence': 69, 'date': 'no date', 'surface_temperature_celcius': 45}]]
# no fire
# {'station': 1, 'date': datetime.datetime(2022, 1, 25, 0, 0), 'air_temperature_celcius': 11, 'relative_humidity': 43.2, 'windspeed_knots': 5.5, 'max_wind_speed': 8.0, 'precipitation': ' 0.00G', 'GHI_w/m2': 100, 'latitude': -37.376, 'longitude': 148.042, '_id': ObjectId('628b45e08240717ef08b4863')}
#
#
# rows_in_batch
# ...
# no fire
# {'station': 1, 'date': datetime.datetime(2022, 4, 5, 0, 0), 'air_temperature_celcius': 16, 'relative_humidity': 46.7, 'windspeed_knots': 10.0, 'max_wind_speed': 16.9, 'precipitation': ' 0.00I', 'GHI_w/m2': 141, 'latitude': -37.591, 'longitude': 149.33, '_id': ObjectId('628b489c8240717ef08b48b0')}
# rows_in_batch
# [['producer3', {'latitude': -37.399, 'longitude': 148.08100000000002, 'datetime': 'no date', 'confidence': 100, 'date': 'no date', 'surface_temperature_celcius': 84}], ['producer2', {'latitude': -36.2549, 'longitude': 141.9908, 'datetime': 'no date', 'confidence': 69, 'date': 'no date', 'surface_temperature_celcius': 44}], ['producer3', {'latitude': -37.665, 'longitude': 142.1339, 'datetime': 'no date', 'confidence': 74, 'date': 'no date', 'surface_temperature_celcius': 48}], ['producer2', {'latitude': -37.5422, 'longitude': 143.2276, 'datetime': 'no date', 'confidence': 75, 'date': 'no date', 'surface_temperature_celcius': 49}], ['producer3', {'latitude': -36.3585, 'longitude': 141.5686, 'datetime': 'no date', 'confidence': 72, 'date': 'no date', 'surface_temperature_celcius': 47}], ['producer2', {'latitude': -37.59, 'longitude': 149.31, 'datetime': 'no date', 'confidence': 51, 'date': 'no date', 'surface_temperature_celcius': 42}], ['producer3', {'latitude': -37.0653, 'longitude': 141.0674, 'datetime': 'no date', 'confidence': 80, 'date': 'no date', 'surface_temperature_celcius': 53}], ['producer2', {'latitude': -36.1925, 'longitude': 145.93, 'datetime': 'no date', 'confidence': 97, 'date': 'no date', 'surface_temperature_celcius': 79}], ['producer3', {'latitude': -35.9903, 'longitude': 142.2708, 'datetime': 'no date', 'confidence': 69, 'date': 'no date', 'surface_temperature_celcius': 45}], ['producer1', {'station': 1, 'date': '06/04/2022', 'air_temperature_celcius': 9, 'relative_humidity': 41.9, 'windspeed_knots': 9.2, 'max_wind_speed': 14.0, 'precipitation': ' 0.12G', 'GHI_w/m2': 82, 'latitude': -36.8741, 'longitude': 143.91}]]
# no fire
# {'station': 1, 'date': datetime.datetime(2022, 4, 6, 0, 0), 'air_temperature_celcius': 9, 'relative_humidity': 41.9, 'windspeed_knots': 9.2, 'max_wind_speed': 14.0, 'precipitation': ' 0.12G', 'GHI_w/m2': 82, 'latitude': -36.8741, 'longitude': 143.91, '_id': ObjectId('628b48a68240717ef08b48b1')}
#
#
# rows_in_batch
# [['producer2', {'latitude': -38.116, 'longitude': 143.81799999999998, 'datetime': 'no date', 'confidence': 76, 'date': 'no date', 'surface_temperature_celcius': 43}], ['producer3', {'latitude': -36.3362, 'longitude': 141.4973, 'datetime': 'no date', 'confidence': 78, 'date': 'no date', 'surface_temperature_celcius': 52}], ['producer2', {'latitude': -38.4792, 'longitude': 146.3081, 'datetime': 'no date', 'confidence': 89, 'date': 'no date', 'surface_temperature_celcius': 65}], ['producer3', {'latitude': -36.9442, 'longitude': 142.9619, 'datetime': 'no date', 'confidence': 86, 'date': 'no date', 'surface_temperature_celcius': 61}], ['producer2', {'latitude': -37.5799, 'longitude': 142.7451, 'datetime': 'no date', 'confidence': 84, 'date': 'no date', 'surface_temperature_celcius': 58}], ['producer3', {'latitude': -36.1546, 'longitude': 141.8146, 'datetime': 'no date', 'confidence': 88, 'date': 'no date', 'surface_temperature_celcius': 74}], ['producer2', {'latitude': -36.1698, 'longitude': 142.0536, 'datetime': 'no date', 'confidence': 84, 'date': 'no date', 'surface_temperature_celcius': 58}], ['producer3', {'latitude': -37.5687, 'longitude': 143.2121, 'datetime': 'no date', 'confidence': 62, 'date': 'no date', 'surface_temperature_celcius': 41}], ['producer2', {'latitude': -37.6638, 'longitude': 142.8268, 'datetime': 'no date', 'confidence': 73, 'date': 'no date', 'surface_temperature_celcius': 47}], ['producer3', {'latitude': -36.1112, 'longitude': 146.5388, 'datetime': 'no date', 'confidence': 67, 'date': 'no date', 'surface_temperature_celcius': 43}], ['producer1', {'station': 1, 'date': '07/04/2022', 'air_temperature_celcius': 15, 'relative_humidity': 47.7, 'windspeed_knots': 5.9, 'max_wind_speed': 13.0, 'precipitation': ' 0.00I', 'GHI_w/m2': 131, 'latitude': -36.543, 'longitude': 141.138}]]
# no fire
# {'station': 1, 'date': datetime.datetime(2022, 4, 7, 0, 0), 'air_temperature_celcius': 15, 'relative_humidity': 47.7, 'windspeed_knots': 5.9, 'max_wind_speed': 13.0, 'precipitation': ' 0.00I', 'GHI_w/m2': 131, 'latitude': -36.543, 'longitude': 141.138, '_id': ObjectId('628b48b08240717ef08b48b2')}
#
#
# rows_in_batch
# [['producer2', {'latitude': -37.466, 'longitude': 148.1, 'datetime': 'no date', 'confidence': 50, 'date': 'no date', 'surface_temperature_celcius': 29}], ['producer3', {'latitude': -36.8616, 'longitude': 142.8025, 'datetime': 'no date', 'confidence': 90, 'date': 'no date', 'surface_temperature_celcius': 78}], ['producer2', {'latitude': -36.4317, 'longitude': 143.0967, 'datetime': 'no date', 'confidence': 64, 'date': 'no date', 'surface_temperature_celcius': 42}], ['producer3', {'latitude': -36.5642, 'longitude': 142.5943, 'datetime': 'no date', 'confidence': 51, 'date': 'no date', 'surface_temperature_celcius': 38}], ['producer2', {'latitude': -37.7583, 'longitude': 143.41, 'datetime': 'no date', 'confidence': 70, 'date': 'no date', 'surface_temperature_celcius': 45}], ['producer3', {'latitude': -37.8937, 'longitude': 147.1785, 'datetime': 'no date', 'confidence': 51, 'date': 'no date', 'surface_temperature_celcius': 38}], ['producer2', {'latitude': -36.3579, 'longitude': 146.1268, 'datetime': 'no date', 'confidence': 63, 'date': 'no date', 'surface_temperature_celcius': 42}], ['producer3', {'latitude': -37.8375, 'longitude': 143.4153, 'datetime': 'no date', 'confidence': 52, 'date': 'no date', 'surface_temperature_celcius': 39}], ['producer2', {'latitude': -36.4673, 'longitude': 145.7291, 'datetime': 'no date', 'confidence': 79, 'date': 'no date', 'surface_temperature_celcius': 52}], ['producer3', {'latitude': -37.0924, 'longitude': 141.89700000000002, 'datetime': 'no date', 'confidence': 97, 'date': 'no date', 'surface_temperature_celcius': 80}], ['producer1', {'station': 1, 'date': '08/04/2022', 'air_temperature_celcius': 24, 'relative_humidity': 62.3, 'windspeed_knots': 7.0, 'max_wind_speed': 13.0, 'precipitation': ' 0.00I', 'GHI_w/m2': 185, 'latitude': -37.903, 'longitude': 145.25}]]
# no fire
# {'station': 1, 'date': datetime.datetime(2022, 4, 8, 0, 0), 'air_temperature_celcius': 24, 'relative_humidity': 62.3, 'windspeed_knots': 7.0, 'max_wind_speed': 13.0, 'precipitation': ' 0.00I', 'GHI_w/m2': 185, 'latitude': -37.903, 'longitude': 145.25, '_id': ObjectId('628b48ba8240717ef08b48b3')}
#
#
# rows_in_batch
# [['producer2', {'latitude': -37.4322, 'longitude': 143.1602, 'datetime': 'no date', 'confidence': 69, 'date': 'no date', 'surface_temperature_celcius': 45}], ['producer3', {'latitude': -38.3871, 'longitude': 146.3082, 'datetime': 'no date', 'confidence': 78, 'date': 'no date', 'surface_temperature_celcius': 51}], ['producer2', {'latitude': -35.0691, 'longitude': 141.4546, 'datetime': 'no date', 'confidence': 80, 'date': 'no date', 'surface_temperature_celcius': 56}], ['producer3', {'latitude': -35.4173, 'longitude': 143.2041, 'datetime': 'no date', 'confidence': 54, 'date': 'no date', 'surface_temperature_celcius': 39}], ['producer2', {'latitude': -36.3313, 'longitude': 141.0017, 'datetime': 'no date', 'confidence': 94, 'date': 'no date', 'surface_temperature_celcius': 73}], ['producer3', {'latitude': -37.3165, 'longitude': 147.4932, 'datetime': 'no date', 'confidence': 93, 'date': 'no date', 'surface_temperature_celcius': 72}], ['producer2', {'latitude': -37.236999999999995, 'longitude': 142.141, 'datetime': 'no date', 'confidence': 100, 'date': 'no date', 'surface_temperature_celcius': 112}], ['producer3', {'latitude': -36.7309, 'longitude': 147.1227, 'datetime': 'no date', 'confidence': 89, 'date': 'no date', 'surface_temperature_celcius': 42}], ['producer2', {'latitude': -35.8261, 'longitude': 143.7665, 'datetime': 'no date', 'confidence': 100, 'date': 'no date', 'surface_temperature_celcius': 111}], ['producer3', {'latitude': -36.4348, 'longitude': 141.3, 'datetime': 'no date', 'confidence': 78, 'date': 'no date', 'surface_temperature_celcius': 52}], ['producer1', {'station': 1, 'date': '09/04/2022', 'air_temperature_celcius': 20, 'relative_humidity': 59.7, 'windspeed_knots': 8.6, 'max_wind_speed': 15.9, 'precipitation': ' 0.01G', 'GHI_w/m2': 158, 'latitude': -37.954, 'longitude': 143.918}]]
# no fire
# {'station': 1, 'date': datetime.datetime(2022, 4, 9, 0, 0), 'air_temperature_celcius': 20, 'relative_humidity': 59.7, 'windspeed_knots': 8.6, 'max_wind_speed': 15.9, 'precipitation': ' 0.01G', 'GHI_w/m2': 158, 'latitude': -37.954, 'longitude': 143.918, '_id': ObjectId('628b48c48240717ef08b48b4')}
# rows_in_batch
# [['producer2', {'latitude': -36.3126, 'longitude': 145.8104, 'datetime': 'no date', 'confidence': 76, 'date': 'no date', 'surface_temperature_celcius': 63}], ['producer3', {'latitude': -37.3601, 'longitude': 145.8519, 'datetime': 'no date', 'confidence': 82, 'date': 'no date', 'surface_temperature_celcius': 62}], ['producer2', {'latitude': -36.8237, 'longitude': 141.4881, 'datetime': 'no date', 'confidence': 84, 'date': 'no date', 'surface_temperature_celcius': 58}], ['producer3', {'latitude': -38.0219, 'longitude': 141.2238, 'datetime': 'no date', 'confidence': 76, 'date': 'no date', 'surface_temperature_celcius': 62}], ['producer2', {'latitude': -35.2464, 'longitude': 141.1143, 'datetime': 'no date', 'confidence': 98, 'date': 'no date', 'surface_temperature_celcius': 45}], ['producer3', {'latitude': -38.036, 'longitude': 143.9012, 'datetime': 'no date', 'confidence': 67, 'date': 'no date', 'surface_temperature_celcius': 45}], ['producer2', {'latitude': -36.2726, 'longitude': 145.506, 'datetime': 'no date', 'confidence': 77, 'date': 'no date', 'surface_temperature_celcius': 50}], ['producer3', {'latitude': -37.9071, 'longitude': 143.53799999999998, 'datetime': 'no date', 'confidence': 100, 'date': 'no date', 'surface_temperature_celcius': 88}], ['producer2', {'latitude': -36.0077, 'longitude': 141.7747, 'datetime': 'no date', 'confidence': 100, 'date': 'no date', 'surface_temperature_celcius': 93}], ['producer3', {'latitude': -37.294000000000004, 'longitude': 141.232, 'datetime': 'no date', 'confidence': 100, 'date': 'no date', 'surface_temperature_celcius': 87}], ['producer1', {'station': 1, 'date': '10/04/2022', 'air_temperature_celcius': 31, 'relative_humidity': 61.9, 'windspeed_knots': 14.1, 'max_wind_speed': 23.9, 'precipitation': ' 0.00I', 'GHI_w/m2': 239, 'latitude': -37.637, 'longitude': 146.28799999999998}]]
# no fire
# {'station': 1, 'date': datetime.datetime(2022, 4, 10, 0, 0), 'air_temperature_celcius': 31, 'relative_humidity': 61.9, 'windspeed_knots': 14.1, 'max_wind_speed': 23.9, 'precipitation': ' 0.00I', 'GHI_w/m2': 239, 'latitude': -37.637, 'longitude': 146.28799999999998, '_id': ObjectId('628b48ce8240717ef08b48b5')}
#
#
# rows_in_batch
# [['producer2', {'latitude': -36.1401, 'longitude': 146.0217, 'datetime': 'no date', 'confidence': 68, 'date': 'no date', 'surface_temperature_celcius': 44}], ['producer3', {'latitude': -36.2209, 'longitude': 141.5804, 'datetime': 'no date', 'confidence': 67, 'date': 'no date', 'surface_temperature_celcius': 43}], ['producer2', {'latitude': -36.0749, 'longitude': 143.4058, 'datetime': 'no date', 'confidence': 92, 'date': 'no date', 'surface_temperature_celcius': 70}], ['producer3', {'latitude': -36.4032, 'longitude': 144.0604, 'datetime': 'no date', 'confidence': 69, 'date': 'no date', 'surface_temperature_celcius': 45}], ['producer2', {'latitude': -35.4941, 'longitude': 143.4974, 'datetime': 'no date', 'confidence': 78, 'date': 'no date', 'surface_temperature_celcius': 51}], ['producer3', {'latitude': -36.301, 'longitude': 143.2349, 'datetime': 'no date', 'confidence': 70, 'date': 'no date', 'surface_temperature_celcius': 45}], ['producer2', {'latitude': -36.1337, 'longitude': 146.1243, 'datetime': 'no date', 'confidence': 61, 'date': 'no date', 'surface_temperature_celcius': 41}], ['producer3', {'latitude': -35.554, 'longitude': 143.30700000000002, 'datetime': 'no date', 'confidence': 67, 'date': 'no date', 'surface_temperature_celcius': 53}], ['producer2', {'latitude': -36.914, 'longitude': 143.0283, 'datetime': 'no date', 'confidence': 88, 'date': 'no date', 'surface_temperature_celcius': 64}], ['producer3', {'latitude': -35.6871, 'longitude': 143.5235, 'datetime': 'no date', 'confidence': 90, 'date': 'no date', 'surface_temperature_celcius': 68}]]
# rows_in_batch
# [['producer2', {'latitude': -36.2685, 'longitude': 141.0912, 'datetime': 'no date', 'confidence': 60, 'date': 'no date', 'surface_temperature_celcius': 40}], ['producer3', {'latitude': -36.8922, 'longitude': 145.1252, 'datetime': 'no date', 'confidence': 60, 'date': 'no date', 'surface_temperature_celcius': 40}], ['producer2', {'latitude': -35.889, 'longitude': 145.614, 'datetime': 'no date', 'confidence': 82, 'date': 'no date', 'surface_temperature_celcius': 56}], ['producer3', {'latitude': -36.3874, 'longitude': 144.8724, 'datetime': 'no date', 'confidence': 78, 'date': 'no date', 'surface_temperature_celcius': 51}], ['producer2', {'latitude': -36.6843, 'longitude': 141.5899, 'datetime': 'no date', 'confidence': 65, 'date': 'no date', 'surface_temperature_celcius': 43}], ['producer3', {'latitude': -36.4611, 'longitude': 143.14600000000002, 'datetime': 'no date', 'confidence': 55, 'date': 'no date', 'surface_temperature_celcius': 48}], ['producer3', {'latitude': -36.1815, 'longitude': 142.09, 'datetime': 'no date', 'confidence': 78, 'date': 'no date', 'surface_temperature_celcius': 52}], ['producer3', {'latitude': -36.0852, 'longitude': 141.7112, 'datetime': 'no date', 'confidence': 100, 'date': 'no date', 'surface_temperature_celcius': 64}]]
# ERROR:root:KeyboardInterrupt while sending command.
# Traceback (most recent call last):
#   File "/home/student/.local/lib/python3.8/site-packages/py4j/java_gateway.py", line 1038, in send_command
#     response = connection.send_command(command)
#   File "/home/student/.local/lib/python3.8/site-packages/py4j/clientserver.py", line 475, in send_command
#     answer = smart_decode(self.stream.readline()[:-1])
#   File "/usr/lib/python3.8/socket.py", line 669, in readinto
#     return self._sock.recv_into(b)
# KeyboardInterrupt
# Interrupted by CTRL-C. Stopped query
